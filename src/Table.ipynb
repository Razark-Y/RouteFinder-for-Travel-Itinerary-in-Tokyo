# %%
import pandas as pd
import pickle
with open('graph.pkl', 'rb') as file:
    data = pickle.load(file)
df = pd.DataFrame(data)
df.fillna(0, inplace=True)
df.head(20)
# Out:
#                            Haneda Airport  Hachikō Memorial Statue  \
# Hachikō Memorial Statue          0.593457                 0.000000
# Tokyo Skytree                    0.756747                 0.294262
# Tokyo Tower                      0.606710                 0.141043
# Sensō-ji                         0.734188                 0.271704
# Tsukiji Outer Market             0.585216                 0.182390
# Imperial Palace                  0.651916                 0.138479
# Nezu Shrine                      0.742111                 0.258549
# Art Aquarium museum              0.595672                 0.142870
# Harajuku Street                  0.645695                 0.068580
# Ueno Park                        0.693426                 0.249877
# Tokyo Dome                       0.684999                 0.179907
# Shibuya Scramble Crossing        0.593071                 0.011647
# Chidorigafuchi Moat              0.678861                 0.138372
# ...
